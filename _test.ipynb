# %%
labels = [f'{i:02d}' for i in [1, 2, 3]] * 3
for i, label in enumerate(labels):
  if '1' in label: labels[i] = f'{label}-04'
labels = [labels[:] for _ in range(9)]
labels
# Out:
# [['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03'],
#  ['01-04', '02', '03', '01-04', '02', '03', '01-04', '02', '03']]

# %%
import SiN.cfg as cfg

def aa(f):
  print(f.wg)
  
aa(cfg)
# Out:
# 0.9
